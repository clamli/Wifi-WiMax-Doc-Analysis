# %%
#showing 
import pickle

# %%
fileName = pickle.load(open("computedFiles.dat", "rb"))

# %%
wordFreqArray  = pickle.load(open("wordFreqArray.dat", "rb"))
featureName = pickle.load(open("featureName.dat", "rb"))

# %%
len(featureName)
# Out:
# 449

# %%
featureName
# Out:
# [' an ip-header-compression cs pdu format (ietf rfc 3095) ',
#  ' automatic repeat request',
#  ' generic mac header ',
#  ' hashed message authentication code ',
#  ' medium access control layer ',
#  ' message integrity check',
#  ' unsolicited grant service ',
#  ' uplink',
#  '1-bit',
#  'A3',
#  'AB',
#  'ACK',
#  'AP',
#  'CT',
#  'ID',
#  'IEEE 802.16',
#  'IETF',
#  'LG',
#  'MA',
#  'MR',
#  'NAK',
#  'NIST',
#  'R&D',
#  'RF',
#  'RFC',
#  'RSA',
#  'RX',
#  'T1',
#  'TBA',
#  'TBD',
#  'URL',
#  'WG',
#  'X.509',
#  'access',
#  'account',
#  'acknowledgement',
#  'acknowledgment',
#  'acquisition',
#  'adaptation',
#  'adaptive antenna system ',
#  'adaptive channel selection',
#  'adaptive modulation and coding',
#  'addressing',
#  'advanced encryption standard',
#  'air',
#  'algorithm',
#  'allocation',
#  'anchor',
#  'antenna',
#  'application',
#  'architecture',
#  'ascending order',
#  'asynchronous transfer mode',
#  'attachment',
#  'attenuation',
#  'attribute',
#  'authentication',
#  'authentication server',
#  'authentication, authorization, and accounting',
#  'authorization key',
#  'backbone',
#  'bandwidth',
#  'bandwidth allocation',
#  'bandwidth efficiency',
#  'bandwidth request',
#  'base station',
#  'base station descriptor',
#  'best effort',
#  'binary',
#  'binary phase shift keying',
#  'bit',
#  'bit error ratio',
#  'bitmap',
#  'block turbo code',
#  'broadband',
#  'broadband wireless',
#  'broadband wireless access',
#  'broadcast',
#  'broadcasting',
#  'buffer',
#  'byte',
#  'cable',
#  'carrier',
#  'carrier to noise and interference ratio',
#  'carrier-to-interference ratio ',
#  'carrier-to-noise ratio',
#  'cellular',
#  'certificate',
#  'certification authority',
#  'channel',
#  'channel allocation',
#  'channel capacity',
#  'channel quality information',
#  'channel quality information channel',
#  'cipher',
#  'cipher block chaining',
#  'cipher-based message authentication code',
#  'ciphertext',
#  'client',
#  'co-channel interference',
#  'code division multiple access',
#  'code rate',
#  'codebook matrix index ',
#  'codeword',
#  'coexistence',
#  'coexistence control channel',
#  'coexistence neighbor',
#  'coexistence protocol',
#  'coexistence signaling interval',
#  'cognitive radio',
#  'collaborative',
#  'collision',
#  'common part sublayer',
#  'communication',
#  'compression',
#  'configuration',
#  'configure',
#  'confirmation code',
#  'connect',
#  'connection',
#  'connection identifier',
#  'connection management',
#  'connections',
#  'connectivity',
#  'constellation',
#  'control message',
#  'convergence',
#  'convergence sublayer',
#  'convolutional code',
#  'convolutional turbo codes',
#  'coordinated universal time',
#  'copyright',
#  'counter',
#  'cryptographic',
#  'cyclic prefix',
#  'cyclic redundancy check',
#  'data encryption standard',
#  'data rate',
#  'data traffic',
#  'database',
#  'decibels of gain relative to the zero db gain of a free-space isotropic radiator ',
#  'decibels relative to one milliwatt',
#  'decode',
#  'decoder',
#  'decoding',
#  'decryption',
#  'delay',
#  'device',
#  'differential',
#  'digital',
#  'discovery',
#  'distributed',
#  'distributed system',
#  'distribution',
#  'document',
#  'downlink',
#  'downlink channel descriptor',
#  'downlink interval usage code',
#  'downstream',
#  'dynamic',
#  'dynamic channel selection',
#  'dynamic frequency selection',
#  'dynamic host configuration protocol',
#  'dynamic service addition ',
#  'dynamic service addition, change, or deletion',
#  'dynamic service change ',
#  'dynamic service deletion',
#  'editor',
#  'effective isotropic radiated power',
#  'electronic',
#  'electronic code book',
#  'encapsulation',
#  'encoding',
#  'encrypt-decrypt-encrypt',
#  'encryption',
#  'encryption control',
#  'encryption key sequence',
#  'energy detection',
#  'entity',
#  'environment',
#  'exclusive-or',
#  'extended',
#  'extended quiet period',
#  'extensible authentication protocol',
#  'extension',
#  'failure',
#  'fast fourier transform',
#  'federal communications commission',
#  'fixed wireless access',
#  'forward error correction',
#  'forwarding',
#  'fragmentation',
#  'frame',
#  'frame control header',
#  'frame structure',
#  'frames',
#  'framing',
#  'frequency',
#  'frequency division duplex or duplexing',
#  'frequency reuse',
#  'full usage of subchannels',
#  'functionality',
#  'global positioning satellite',
#  'group key encryption key',
#  'handoff',
#  'handover',
#  'handover ranging',
#  'handshake',
#  'hardware',
#  'header',
#  'header check sequence',
#  'header type',
#  'hexadecimal',
#  'hybrid',
#  'hybrid arq',
#  'implementation',
#  'in-band',
#  'incremental redundancy',
#  'indices',
#  'information element',
#  'infrastructure station',
#  'initialization coexistence signaling interval',
#  'initialization vector ',
#  'initializing base station',
#  'integrated',
#  'integrity',
#  'interleaving',
#  'internet protocol',
#  'interoperability',
#  'inverse fast fourier transform',
#  'issue',
#  'key encryption key ',
#  'latency',
#  'least significant bit',
#  'license-exempt',
#  'line of sight',
#  'link',
#  'listen',
#  'local area network',
#  'log',
#  'low-density parity check',
#  'maintenance',
#  'management information base',
#  'map',
#  'matrix',
#  'message access',
#  'message access protocol',
#  'message board',
#  'message digest',
#  'message disposition',
#  'message format',
#  'message header',
#  'message headers',
#  'message integrity check',
#  'message integrity code',
#  'message switching',
#  'message transfer',
#  'message transfer agent',
#  'message unique identifier',
#  'method',
#  'methods',
#  'metropolitan area',
#  'mobile relay station ',
#  'mobile station',
#  'modulation',
#  'modulation coding scheme',
#  'monitor',
#  'most significant bit',
#  'multi-user',
#  'multicast',
#  'multicast and broadcast services',
#  'multichannel multipoint distribution service',
#  'multihop',
#  'multihop relay base station ',
#  'multiple input multiple output',
#  'multiplexing',
#  'negotiation',
#  'neighboring',
#  'network control and management system',
#  'network entry',
#  'nibble',
#  'node',
#  'non line of sight',
#  'non-real-time polling service',
#  'nonce',
#  'not applicable',
#  'nth',
#  'open-loop',
#  'operating base station',
#  'operation coexistence signaling interval',
#  'optimize',
#  'orthogonal frequency division multiple access',
#  'orthogonal frequency division multiplexing',
#  'outage',
#  'packet',
#  'packet error rate',
#  'packet number',
#  'page',
#  'paging',
#  'pairwise master key',
#  'parameters',
#  'parity bit',
#  'partial usage of subchannels',
#  'path',
#  'path loss',
#  'payload',
#  'payload header suppression',
#  'peak to average power ratio',
#  'performance',
#  'persistent allocation',
#  'physical layer',
#  'piggyback',
#  'plaintext',
#  'point coordinator',
#  'point to point',
#  'point-to-multipoint',
#  'port',
#  'post',
#  'prefix',
#  'privacy',
#  'privacy key management',
#  'profile',
#  'propagation',
#  'proprietary',
#  'protocol',
#  'protocol data unit',
#  'proxy',
#  'pseudo random binary sequence',
#  'quadrature amplitude modulation',
#  'quadrature phase-shift keying',
#  'quality of service',
#  'radio resource management ',
#  'ranging',
#  'real-time',
#  'real-time polling service',
#  'receive (abbreviation not used as verb) ',
#  'receive signal strength',
#  'receive signal strength indicator',
#  'receive/transmit transition gap',
#  'regulation',
#  'relay station',
#  'relay zone',
#  'relay zone frame control header ',
#  'relay zone map',
#  'release',
#  'remote',
#  'remote authentication dial-in user service (ietf rfc 2865 [b14]) ',
#  'replay',
#  'request',
#  'request header',
#  'reservation',
#  'resolution',
#  'resource unit',
#  'response',
#  'retransmission',
#  'robust',
#  'round trip delay',
#  'route',
#  'routing',
#  'satellite',
#  'scheduling',
#  'scheme',
#  'sec',
#  'security',
#  'security association',
#  'security association identifier',
#  'security management',
#  'segment',
#  'select',
#  'sequence number',
#  'server',
#  'service',
#  'service access point',
#  'service data unit',
#  'service flow',
#  'service flow identifier ',
#  'service flow management',
#  'service primitive',
#  'session',
#  'sharing',
#  'signal-to-noise ratio',
#  'signatures',
#  'simple network management protocol',
#  'simulation',
#  'single carrier',
#  'solution',
#  'space time coding',
#  'space time transmit diversity',
#  'specifications',
#  'spectrum',
#  'speed',
#  'standard',
#  'static',
#  'station',
#  'stream',
#  'string',
#  'structure',
#  'subcarrier',
#  'sublayer',
#  'subpacket id',
#  'subscriber station',
#  'subscriber station identification (mac address)',
#  'subscriber station uplink radio frequency transmit power control',
#  'subscribers',
#  'success',
#  'suite',
#  'switch',
#  'switched',
#  'switching',
#  'symbol',
#  'synchronization',
#  'synchronous',
#  'technology',
#  'terminal',
#  'the edge',
#  'the way',
#  'threshold',
#  'throughput',
#  'time division duplex or duplexing ',
#  'time slot',
#  'tracking',
#  'traffic',
#  'traffic encryption key',
#  'transmission opportunity',
#  'transmit (abbreviation not used as verb) ',
#  'transmit/receive transition gap',
#  'transport',
#  'triple data encryption standard',
#  'trivial file transfer protocol',
#  'tunneling',
#  'type/length/value',
#  'unicast',
#  'uplink',
#  'uplink channel descriptor',
#  'uplink interval usage code ',
#  'upstream',
#  'virtual',
#  'web site',
#  'window',
#  'wired',
#  'wireless',
#  'wireless access',
#  'wireless high-speed unlicensed metropolitan area networks',
#  'wireless local area network',
#  'wireless metropolitan access network coexistence',
#  'wireless metropolitan area networks',
#  'wireless network',
#  'word',
#  'zone']

# %%
for item in wordFreqArray[0]:
    print(item)
# Out:
#   (0, 113)	1
#   (0, 137)	1
#   (0, 33)	1
#   (0, 440)	2
#   (0, 441)	1
#   (0, 74)	1
#   (0, 75)	1
#   (0, 76)	1
#   (0, 261)	1
#   (0, 275)	1
#   (0, 244)	2
#   (0, 144)	2
#   (0, 115)	1
#   (0, 291)	1
#   (0, 124)	1
#   (0, 328)	1
#   (0, 380)	5
#   (0, 295)	15
#   (0, 309)	5
#   (0, 329)	5
#   (0, 71)	18
#   (0, 129)	6
#   (0, 48)	3
#   (0, 172)	1
#   (0, 383)	1
#   (0, 65)	4
#   (0, 308)	7
#   (0, 437)	1
#   (0, 412)	1
#   (0, 49)	1
#   (0, 169)	1
#   (0, 391)	2
#   (0, 131)	1
#   (0, 154)	2
#   (0, 386)	6
#   (0, 424)	5
#   (0, 15)	5

# %%
## extract 80211 doc
from fileProcessing import *
pdfDir11_1 = "F:\\WireLessNLPGRA\\gitFiles\\Wifi-WiMax-Doc-Analysis\\Spider_Kay\\80211grouper"
pdfDir11_2 = "F:\\WireLessNLPGRA\\gitFiles\\Wifi-WiMax-Doc-Analysis\\Spider_Kay\\80211mentor"
pdfDir16_1 = "F:\\WireLessNLPGRA\\gitFiles\\Wifi-WiMax-Doc-Analysis\\Spider_Kay\\80216mentor"
